# %%
from sagemaker import get_execution_role

role = get_execution_role()
bucket = 'mnistkmeans' # Use the name of your s3 bucket here

# %%
role
# Out:
# 'arn:aws:iam::834811276895:role/service-role/AmazonSageMaker-ExecutionRole-20240504T215427'

# %%
# %%time
import pickle, gzip, numpy, urllib.request, json
import os
with gzip.open('./mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# /home/ec2-user/SageMaker
# ['.sparkmagic', 'test.csv', 'bank_clean.csv', 'MNISTDemo.ipynb', '.ipynb_checkpoints', 'mnist.pkl.gz', 'lost+found', '.Trash-1000', 'train.csv', 'sage_note1.ipynb', 'sageTest.ipynb']
# CPU times: user 681 ms, sys: 308 ms, total: 989 ms
# Wall time: 1.46 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (2,10)


def show_digit(img, caption='', subplot=None):
    if subplot == None:
        _, (subplot) = plt.subplots(1,1)
    imgr = img.reshape((28,28))
    subplot.axis('off')
    subplot.imshow(imgr, cmap='gray')
    plt.title(caption)

show_digit(train_set[0][30], 'This is a {}'.format(train_set[1][30]))

# %%
from sagemaker import KMeans

data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket)
output_location = 's3://{}/kmeans_highlevel_example/output'.format(bucket)

print('training data will be uploaded to: {}'.format(data_location))
print('training artifacts will be uploaded to: {}'.format(output_location))

kmeans = KMeans(role=role,
                train_instance_count=2,
                train_instance_type='ml.c4.8xlarge',
                output_path=output_location,
                k=10,
                epochs=100,
                data_location=data_location)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# training data will be uploaded to: s3://mnistkmeans/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://mnistkmeans/kmeans_highlevel_example/output

# %%
# %%time

kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: kmeans-2024-05-30-13-17-26-835
# 2024-05-30 13:17:27 Starting - Starting the training job...
# 2024-05-30 13:17:41 Starting - Preparing the instances for training...
# 2024-05-30 13:18:13 Downloading - Downloading input data...
# 2024-05-30 13:18:33 Downloading - Downloading the training image...
# 2024-05-30 13:19:18 Training - Training image download completed. Training in progress......Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/30/2024 13:20:04 INFO 140323930539840] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [05/30/2024 13:20:04 INFO 140323930539840] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '100', 'feature_dim': '784', 'force_dense': 'True', 'k': '10'}
# [05/30/2024 13:20:04 INFO 140323930539840] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '100', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [05/30/2024 13:20:06 WARNING 140323930539840] Loggers have already been setup.
# [05/30/2024 13:20:06 INFO 140323930539840] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '100', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [05/30/2024 13:20:06 WARNING 140323930539840] Loggers have already been setup.
# [05/30/2024 13:20:06 INFO 140323930539840] Launching parameter server for role scheduler
# [05/30/2024 13:20:06 INFO 140323930539840] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-76-108.ec2.internal', 'TRAINING_JOB_NAME': 'kmeans-2024-05-30-13-17-26-835', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:834811276895:training-job/kmeans-2024-05-30-13-17-26-835', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-80d22ff3fd6c9c6c3891cf8b1fa6967e094fa551a3c6f817c71d652c8a12401f-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [05/30/2024 13:20:06 INFO 140323930539840] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-76-108.ec2.internal', 'TRAINING_JOB_NAME': 'kmeans-2024-05-30-13-17-26-835', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:834811276895:training-job/kmeans-2024-05-30-13-17-26-835', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-80d22ff3fd6c9c6c3891cf8b1fa6967e094fa551a3c6f817c71d652c8a12401f-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.2.76.108', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# [05/30/2024 13:20:06 INFO 140323930539840] Launching parameter server for role server
# [05/30/2024 13:20:06 INFO 140323930539840] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-76-108.ec2.internal', 'TRAINING_JOB_NAME': 'kmeans-2024-05-30-13-17-26-835', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:834811276895:training-job/kmeans-2024-05-30-13-17-26-835', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-80d22ff3fd6c9c6c3891cf8b1fa6967e094fa551a3c6f817c71d652c8a12401f-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [05/30/2024 13:20:06 INFO 140323930539840] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-76-108.ec2.internal', 'TRAINING_JOB_NAME': 'kmeans-2024-05-30-13-17-26-835', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:834811276895:training-job/kmeans-2024-05-30-13-17-26-835', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-80d22ff3fd6c9c6c3891cf8b1fa6967e094fa551a3c6f817c71d652c8a12401f-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.2.76.108', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# [05/30/2024 13:20:06 INFO 140323930539840] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-76-108.ec2.internal', 'TRAINING_JOB_NAME': 'kmeans-2024-05-30-13-17-26-835', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:834811276895:training-job/kmeans-2024-05-30-13-17-26-835', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-80d22ff3fd6c9c6c3891cf8b1fa6967e094fa551a3c6f817c71d652c8a12401f-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.76.108', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# Process 82 is a shell:scheduler.
# Process 91 is a shell:server.
# Process 7 is a worker.
# [05/30/2024 13:20:06 INFO 140323930539840] Using default worker.
# [05/30/2024 13:20:06 INFO 140323930539840] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/30/2024 13:20:06 INFO 140323930539840] Create Store: dist_async
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [05/30/2024 13:20:07 INFO 140323930539840] nvidia-smi: took 0.030 seconds to run.
# [05/30/2024 13:20:07 INFO 140323930539840] nvidia-smi identified 0 GPUs.
# [05/30/2024 13:20:07 INFO 140323930539840] Number of GPUs being used: 0
# [05/30/2024 13:20:07 INFO 140323930539840] Checkpoint loading and saving are disabled.
# [05/30/2024 13:20:07 INFO 140323930539840] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '100', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [05/30/2024 13:20:07 INFO 140323930539840] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [05/30/2024 13:20:07 INFO 140323930539840] Number of GPUs being used: 0
# [05/30/2024 13:20:07 INFO 140323930539840] number of center slices 1
# #metrics {"StartTime": 1717075207.3618104, "EndTime": 1717075207.3618379, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [2024-05-30 13:20:07.384] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 63, "num_examples": 1, "num_bytes": 15820000}
# [2024-05-30 13:20:07.540] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 155, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140323930539840] #progress_metric: host=algo-1, completed 1.0 % of epochs
# #metrics {"StartTime": 1717075207.3843844, "EndTime": 1717075207.540956, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 30000.0, "count": 1, "min": 30000, "max": 30000}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=159491.36816487944 records/second
# [2024-05-30 13:20:07.653] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 111, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140323930539840] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1717075207.5413206, "EndTime": 1717075207.6533115, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 55000.0, "count": 1, "min": 55000, "max": 55000}, "Total Batches Seen": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=223040.05921778915 records/second
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/30/2024 13:20:04 INFO 140103057602368] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-input.json: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '1', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'true', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': ''}
# [05/30/2024 13:20:04 INFO 140103057602368] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '100', 'feature_dim': '784', 'force_dense': 'True', 'k': '10'}
# [05/30/2024 13:20:04 INFO 140103057602368] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '100', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [05/30/2024 13:20:06 WARNING 140103057602368] Loggers have already been setup.
# [05/30/2024 13:20:06 INFO 140103057602368] Final configuration: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '100', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [05/30/2024 13:20:06 WARNING 140103057602368] Loggers have already been setup.
# [05/30/2024 13:20:06 INFO 140103057602368] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-2-72-1.ec2.internal', 'TRAINING_JOB_NAME': 'kmeans-2024-05-30-13-17-26-835', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:834811276895:training-job/kmeans-2024-05-30-13-17-26-835', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/proxy-80d22ff3fd6c9c6c3891cf8b1fa6967e094fa551a3c6f817c71d652c8a12401f-customer', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'all', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.8/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'SAGEMAKER_MANAGED_WARMPOOL_CACHE_DIRECTORY': '/opt/ml/sagemaker/warmpoolcache', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-1', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'CUDA_VERSION': '11.1', 'HOME': '/root', 'SHLVL': '1', 'CUDA_COMPAT_NDRIVER_SUPPORTED_VERSION': '455.32.00', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '18', 'DMLC_INTERFACE': 'eth0', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.2.76.108', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '2'}
# Process 7 is a worker.
# [05/30/2024 13:20:06 INFO 140103057602368] Using default worker.
# [05/30/2024 13:20:06 INFO 140103057602368] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/30/2024 13:20:06 INFO 140103057602368] Create Store: dist_async
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [05/30/2024 13:20:07 INFO 140103057602368] nvidia-smi: took 0.030 seconds to run.
# [05/30/2024 13:20:07 INFO 140103057602368] nvidia-smi identified 0 GPUs.
# [05/30/2024 13:20:07 INFO 140103057602368] Number of GPUs being used: 0
# [05/30/2024 13:20:07 INFO 140103057602368] Checkpoint loading and saving are disabled.
# [05/30/2024 13:20:07 INFO 140103057602368] Setting up with params: {'init_method': 'random', 'mini_batch_size': '5000', 'epochs': '100', 'extra_center_factor': 'auto', 'local_lloyd_max_iter': '300', 'local_lloyd_tol': '0.0001', 'local_lloyd_init_method': 'kmeans++', 'local_lloyd_num_trials': 'auto', 'half_life_time_size': '0', 'eval_metrics': '["msd"]', 'force_dense': 'True', '_disable_wait_to_read': 'false', '_enable_profiler': 'false', '_kvstore': 'auto', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_num_slices': '1', '_tuning_objective_metric': '', 'feature_dim': '784', 'k': '10'}
# [05/30/2024 13:20:07 INFO 140103057602368] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [05/30/2024 13:20:07 INFO 140103057602368] Number of GPUs being used: 0
# [05/30/2024 13:20:07 INFO 140103057602368] number of center slices 1
# #metrics {"StartTime": 1717075207.3648608, "EndTime": 1717075207.3648872, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 5000.0, "count": 1, "min": 5000, "max": 5000}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [2024-05-30 13:20:07.386] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 65, "num_examples": 1, "num_bytes": 15820000}
# [2024-05-30 13:20:07.529] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 143, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140103057602368] #progress_metric: host=algo-2, completed 1.0 % of epochs
# #metrics {"StartTime": 1717075207.3865745, "EndTime": 1717075207.5302958, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 30000.0, "count": 1, "min": 30000, "max": 30000}, "Total Batches Seen": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=173813.93228627078 records/second
# [2024-05-30 13:20:07.638] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 104, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140103057602368] #progress_metric: host=algo-2, completed 2.0 % of epochs
# #metrics {"StartTime": 1717075207.5304744, "EndTime": 1717075207.639256, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 55000.0, "count": 1, "min": 55000, "max": 55000}, "Total Batches Seen": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=229598.9262074145 records/second
# [2024-05-30 13:20:07.761] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 107, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140323930539840] #progress_metric: host=algo-1, completed 3.0 % of epochs
# #metrics {"StartTime": 1717075207.6534963, "EndTime": 1717075207.761778, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 80000.0, "count": 1, "min": 80000, "max": 80000}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=230638.23984198523 records/second
# [2024-05-30 13:20:07.871] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 106, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140323930539840] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1717075207.7620025, "EndTime": 1717075207.871653, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 105000.0, "count": 1, "min": 105000, "max": 105000}, "Total Batches Seen": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=227612.35985543267 records/second
# [2024-05-30 13:20:07.978] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 106, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140323930539840] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1717075207.872128, "EndTime": 1717075207.9787676, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 130000.0, "count": 1, "min": 130000, "max": 130000}, "Total Batches Seen": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=233579.0357683046 records/second
# [2024-05-30 13:20:08.097] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 114, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140323930539840] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1717075207.979576, "EndTime": 1717075208.0978987, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 155000.0, "count": 1, "min": 155000, "max": 155000}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=211085.99243487205 records/second
# [2024-05-30 13:20:08.200] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 102, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140323930539840] #progress_metric: host=algo-1, completed 7.0 % of epochs
# #metrics {"StartTime": 1717075208.0980878, "EndTime": 1717075208.2012947, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 180000.0, "count": 1, "min": 180000, "max": 180000}, "Total Batches Seen": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=241402.1258423138 records/second
# [2024-05-30 13:20:08.307] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 15, "duration": 101, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140323930539840] #progress_metric: host=algo-1, completed 8.0 % of epochs
# #metrics {"StartTime": 1717075208.2030945, "EndTime": 1717075208.3077245, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 205000.0, "count": 1, "min": 205000, "max": 205000}, "Total Batches Seen": {"sum": 41.0, "count": 1, "min": 41, "max": 41}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=238378.82321916532 records/second
# [2024-05-30 13:20:08.406] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 17, "duration": 98, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140323930539840] #progress_metric: host=algo-1, completed 9.0 % of epochs
# #metrics {"StartTime": 1717075208.3081055, "EndTime": 1717075208.4071312, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 230000.0, "count": 1, "min": 230000, "max": 230000}, "Total Batches Seen": {"sum": 46.0, "count": 1, "min": 46, "max": 46}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=252134.26950081755 records/second
# [2024-05-30 13:20:08.521] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 19, "duration": 111, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140323930539840] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1717075208.4073803, "EndTime": 1717075208.5215406, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 255000.0, "count": 1, "min": 255000, "max": 255000}, "Total Batches Seen": {"sum": 51.0, "count": 1, "min": 51, "max": 51}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=218735.8671617506 records/second
# [2024-05-30 13:20:08.625] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 103, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140323930539840] #progress_metric: host=algo-1, completed 11.0 % of epochs
# #metrics {"StartTime": 1717075208.521764, "EndTime": 1717075208.6260014, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 280000.0, "count": 1, "min": 280000, "max": 280000}, "Total Batches Seen": {"sum": 56.0, "count": 1, "min": 56, "max": 56}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=239582.51460010785 records/second
# [2024-05-30 13:20:07.745] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 105, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140103057602368] #progress_metric: host=algo-2, completed 3.0 % of epochs
# #metrics {"StartTime": 1717075207.6394265, "EndTime": 1717075207.74567, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 80000.0, "count": 1, "min": 80000, "max": 80000}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=235084.0614021518 records/second
# [2024-05-30 13:20:07.853] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 107, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140103057602368] #progress_metric: host=algo-2, completed 4.0 % of epochs
# #metrics {"StartTime": 1717075207.7458434, "EndTime": 1717075207.853643, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 105000.0, "count": 1, "min": 105000, "max": 105000}, "Total Batches Seen": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=231691.10092249903 records/second
# [2024-05-30 13:20:07.958] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 104, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:07 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:07 INFO 140103057602368] #progress_metric: host=algo-2, completed 5.0 % of epochs
# #metrics {"StartTime": 1717075207.853826, "EndTime": 1717075207.9588523, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 130000.0, "count": 1, "min": 130000, "max": 130000}, "Total Batches Seen": {"sum": 26.0, "count": 1, "min": 26, "max": 26}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:07 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=237794.44347433661 records/second
# [2024-05-30 13:20:08.058] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 95, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140103057602368] #progress_metric: host=algo-2, completed 6.0 % of epochs
# #metrics {"StartTime": 1717075207.959033, "EndTime": 1717075208.058836, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 155000.0, "count": 1, "min": 155000, "max": 155000}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=250222.16495091372 records/second
# [2024-05-30 13:20:08.150] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 90, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140103057602368] #progress_metric: host=algo-2, completed 7.0 % of epochs
# #metrics {"StartTime": 1717075208.0590608, "EndTime": 1717075208.1504009, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 180000.0, "count": 1, "min": 180000, "max": 180000}, "Total Batches Seen": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=273382.76548926363 records/second
# [2024-05-30 13:20:08.270] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 15, "duration": 116, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140103057602368] #progress_metric: host=algo-2, completed 8.0 % of epochs
# #metrics {"StartTime": 1717075208.1505728, "EndTime": 1717075208.2708533, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 205000.0, "count": 1, "min": 205000, "max": 205000}, "Total Batches Seen": {"sum": 41.0, "count": 1, "min": 41, "max": 41}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=207668.4200519678 records/second
# [2024-05-30 13:20:08.368] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 17, "duration": 97, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140103057602368] #progress_metric: host=algo-2, completed 9.0 % of epochs
# #metrics {"StartTime": 1717075208.2710352, "EndTime": 1717075208.3686981, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 230000.0, "count": 1, "min": 230000, "max": 230000}, "Total Batches Seen": {"sum": 46.0, "count": 1, "min": 46, "max": 46}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=255705.9631137047 records/second
# [2024-05-30 13:20:08.500] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 19, "duration": 128, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140103057602368] #progress_metric: host=algo-2, completed 10.0 % of epochs
# #metrics {"StartTime": 1717075208.368881, "EndTime": 1717075208.5010257, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 255000.0, "count": 1, "min": 255000, "max": 255000}, "Total Batches Seen": {"sum": 51.0, "count": 1, "min": 51, "max": 51}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:08 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=189026.95579595582 records/second
# [2024-05-30 13:20:08.606] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 104, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:08 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:08 INFO 140103057602368] #progress_metric: host=algo-2, completed 11.0 % of epochs
# ...
# [05/30/2024 13:20:18 INFO 140323930539840] #progress_metric: host=algo-1, completed 99.0 % of epochs
# #metrics {"StartTime": 1717075218.2434428, "EndTime": 1717075218.3369622, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2480000.0, "count": 1, "min": 2480000, "max": 2480000}, "Total Batches Seen": {"sum": 496.0, "count": 1, "min": 496, "max": 496}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:18 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=267021.82111725956 records/second
# [2024-05-30 13:20:18.438] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 199, "duration": 98, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:18 INFO 140323930539840] processed a total of 25000 examples
# [05/30/2024 13:20:18 INFO 140323930539840] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1717075218.3371632, "EndTime": 1717075218.4392858, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2505000.0, "count": 1, "min": 2505000, "max": 2505000}, "Total Batches Seen": {"sum": 501.0, "count": 1, "min": 501, "max": 501}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:18 INFO 140323930539840] #throughput_metric: host=algo-1, train throughput=244452.37079466323 records/second
# [05/30/2024 13:20:18 INFO 140323930539840] shrinking 100 centers into 10
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #0. Current mean square distance 12.506003
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #1. Current mean square distance 12.105018
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #2. Current mean square distance 12.455950
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #3. Current mean square distance 12.540055
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #4. Current mean square distance 12.592012
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #5. Current mean square distance 12.147217
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #6. Current mean square distance 12.503705
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #7. Current mean square distance 12.220294
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #8. Current mean square distance 12.038170
# [05/30/2024 13:20:18 INFO 140323930539840] local kmeans attempt #9. Current mean square distance 12.417459
# [05/30/2024 13:20:18 INFO 140323930539840] finished shrinking process. Mean Square Distance = 12
# [05/30/2024 13:20:18 INFO 140323930539840] #quality_metric: host=algo-1, train msd <loss>=12.038169860839844
# [05/30/2024 13:20:18 INFO 140323930539840] batch data loading with context took: 41.1888%, (4.667675 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] compute all data-center distances: point norm took: 14.7458%, (1.671052 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] gradient: cluster center took: 11.7991%, (1.337115 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] collect from kv store took: 8.8712%, (1.005321 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] compute all data-center distances: inner product took: 8.4060%, (0.952602 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] predict compute msd took: 4.4018%, (0.498831 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] splitting centers key-value pair took: 4.3181%, (0.489340 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] gradient: cluster size  took: 2.5055%, (0.283938 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] compute all data-center distances: center norm took: 1.4965%, (0.169594 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] gradient: one_hot took: 1.2144%, (0.137623 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] update state and report convergance took: 0.8549%, (0.096883 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] update set-up time took: 0.1107%, (0.012543 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] predict minus dist took: 0.0871%, (0.009873 secs)
# [05/30/2024 13:20:18 INFO 140323930539840] TOTAL took: 11.332390069961548
# [05/30/2024 13:20:18 INFO 140323930539840] Number of GPUs being used: 0
# #metrics {"StartTime": 1717075207.320422, "EndTime": 1717075218.6237652, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 20.26963233947754, "count": 1, "min": 20.26963233947754, "max": 20.26963233947754}, "epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "update.time": {"sum": 11004.379034042358, "count": 100, "min": 93.40453147888184, "max": 156.2058925628662}, "_shrink.time": {"sum": 175.7335662841797, "count": 1, "min": 175.7335662841797, "max": 175.7335662841797}, "finalize.time": {"sum": 183.73847007751465, "count": 1, "min": 183.73847007751465, "max": 183.73847007751465}, "model.serialize.time": {"sum": 0.15282630920410156, "count": 1, "min": 0.15282630920410156, "max": 0.15282630920410156}}}
# [05/30/2024 13:20:18 INFO 140323930539840] Test data is not provided.
# #metrics {"StartTime": 1717075218.6238332, "EndTime": 1717075218.6270351, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 15.615701675415039, "count": 1, "min": 15.615701675415039, "max": 15.615701675415039}, "totaltime": {"sum": 12513.359069824219, "count": 1, "min": 12513.359069824219, "max": 12513.359069824219}}}
# [2024-05-30 13:20:17.806] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 193, "duration": 103, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:17 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:17 INFO 140103057602368] #progress_metric: host=algo-2, completed 97.0 % of epochs
# #metrics {"StartTime": 1717075217.7010007, "EndTime": 1717075217.8069594, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 96, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2430000.0, "count": 1, "min": 2430000, "max": 2430000}, "Total Batches Seen": {"sum": 486.0, "count": 1, "min": 486, "max": 486}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 97.0, "count": 1, "min": 97, "max": 97}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:17 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=235701.79421589035 records/second
# [2024-05-30 13:20:17.899] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 195, "duration": 92, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:17 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:17 INFO 140103057602368] #progress_metric: host=algo-2, completed 98.0 % of epochs
# #metrics {"StartTime": 1717075217.8071356, "EndTime": 1717075217.899831, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 97, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2455000.0, "count": 1, "min": 2455000, "max": 2455000}, "Total Batches Seen": {"sum": 491.0, "count": 1, "min": 491, "max": 491}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 98.0, "count": 1, "min": 98, "max": 98}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:17 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=269407.9107948049 records/second
# [2024-05-30 13:20:18.003] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 197, "duration": 103, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:18 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:18 INFO 140103057602368] #progress_metric: host=algo-2, completed 99.0 % of epochs
# #metrics {"StartTime": 1717075217.900003, "EndTime": 1717075218.0043316, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2480000.0, "count": 1, "min": 2480000, "max": 2480000}, "Total Batches Seen": {"sum": 496.0, "count": 1, "min": 496, "max": 496}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:18 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=239390.52872135682 records/second
# [2024-05-30 13:20:18.107] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 199, "duration": 101, "num_examples": 5, "num_bytes": 79100000}
# [05/30/2024 13:20:18 INFO 140103057602368] processed a total of 25000 examples
# [05/30/2024 13:20:18 INFO 140103057602368] #progress_metric: host=algo-2, completed 100.0 % of epochs
# #metrics {"StartTime": 1717075218.004505, "EndTime": 1717075218.1083324, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2505000.0, "count": 1, "min": 2505000, "max": 2505000}, "Total Batches Seen": {"sum": 501.0, "count": 1, "min": 501, "max": 501}, "Max Records Seen Between Resets": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Max Batches Seen Between Resets": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 25000.0, "count": 1, "min": 25000, "max": 25000}, "Number of Batches Since Last Reset": {"sum": 5.0, "count": 1, "min": 5, "max": 5}}}
# [05/30/2024 13:20:18 INFO 140103057602368] #throughput_metric: host=algo-2, train throughput=240551.49631226988 records/second
# [05/30/2024 13:20:18 INFO 140103057602368] shrinking 100 centers into 10
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #0. Current mean square distance 12.440383
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #1. Current mean square distance 12.399974
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #2. Current mean square distance 12.359116
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #3. Current mean square distance 13.140080
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #4. Current mean square distance 12.166088
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #5. Current mean square distance 12.247551
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #6. Current mean square distance 12.584291
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #7. Current mean square distance 12.737994
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #8. Current mean square distance 12.428639
# [05/30/2024 13:20:18 INFO 140103057602368] local kmeans attempt #9. Current mean square distance 12.289248
# [05/30/2024 13:20:18 INFO 140103057602368] finished shrinking process. Mean Square Distance = 12
# [05/30/2024 13:20:18 INFO 140103057602368] #quality_metric: host=algo-2, train msd <loss>=12.166088104248047
# [05/30/2024 13:20:18 INFO 140103057602368] batch data loading with context took: 35.1781%, (3.812992 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] collect from kv store took: 22.4076%, (2.428785 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] compute all data-center distances: point norm took: 13.0893%, (1.418767 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] gradient: cluster center took: 10.4087%, (1.128207 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] compute all data-center distances: inner product took: 7.7822%, (0.843522 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] predict compute msd took: 3.6153%, (0.391863 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] splitting centers key-value pair took: 2.5326%, (0.274515 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] gradient: cluster size  took: 2.1144%, (0.229186 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] gradient: one_hot took: 1.0099%, (0.109463 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] update state and report convergance took: 0.8686%, (0.094144 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] compute all data-center distances: center norm took: 0.8087%, (0.087653 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] update set-up time took: 0.1000%, (0.010839 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] predict minus dist took: 0.0846%, (0.009174 secs)
# [05/30/2024 13:20:18 INFO 140103057602368] TOTAL took: 10.839110851287842
# [05/30/2024 13:20:18 INFO 140103057602368] Number of GPUs being used: 0
# [05/30/2024 13:20:18 INFO 140103057602368] No model is serialized on a non-master node
# #metrics {"StartTime": 1717075207.320786, "EndTime": 1717075218.6715827, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 22.822141647338867, "count": 1, "min": 22.822141647338867, "max": 22.822141647338867}, "epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "update.time": {"sum": 10683.435678482056, "count": 100, "min": 84.91134643554688, "max": 143.58043670654297}, "_shrink.time": {"sum": 224.60436820983887, "count": 1, "min": 224.60436820983887, "max": 224.60436820983887}, "finalize.time": {"sum": 231.520414352417, "count": 1, "min": 231.520414352417, "max": 231.520414352417}, "model.serialize.time": {"sum": 0.04172325134277344, "count": 1, "min": 0.04172325134277344, "max": 0.04172325134277344}}}
# [05/30/2024 13:20:18 INFO 140103057602368] Test data is not provided.
# #metrics {"StartTime": 1717075218.6716568, "EndTime": 1717075218.6756346, "Dimensions": {"Algorithm": "AWS/KMeansWebscale", "Host": "algo-2", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 6.329536437988281, "count": 1, "min": 6.329536437988281, "max": 6.329536437988281}, "totaltime": {"sum": 12523.082494735718, "count": 1, "min": 12523.082494735718, "max": 12523.082494735718}}}
#
# 2024-05-30 13:20:39 Completed - Training job completed
# Training seconds: 290
# Billable seconds: 290
# CPU times: user 12.1 s, sys: 350 ms, total: 12.4 s
# Wall time: 4min

# %%
# %%time

kmeans_predictor = kmeans.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# INFO:sagemaker.image_uris:Same images used for training and inference. Defaulting to image scope: inference.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating model with name: kmeans-2024-05-30-13-22-08-787
# INFO:sagemaker:Creating endpoint-config with name kmeans-2024-05-30-13-22-08-787
# INFO:sagemaker:Creating endpoint with name kmeans-2024-05-30-13-22-08-787
# -------!CPU times: user 99.6 ms, sys: 10 ms, total: 110 ms
# Wall time: 4min 2s

# %%
# %%time 

result = kmeans_predictor.predict(valid_set[0][0:100])
clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]
# Out:
# CPU times: user 44.5 ms, sys: 109 µs, total: 44.6 ms
# Wall time: 244 ms

# %%
for cluster in range(10):
    print('\n\n\nCluster {}:'.format(int(cluster)))
    digits = [ img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster ]
    height = ((len(digits)-1)//5) + 1
    width = 5
    plt.rcParams["figure.figsize"] = (width,height)
    _, subplots = plt.subplots(height, width)
    subplots = numpy.ndarray.flatten(subplots)
    for subplot, image in zip(subplots, digits):
        show_digit(image, subplot=subplot)
    for subplot in subplots[len(digits):]:
        subplot.axis('off')

    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:

# %%
result = kmeans_predictor.predict(valid_set[0][230:231])
print(result)
# Out:
# [label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 6.29484415
#     }
#   }
# }
# label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 0
#     }
#   }
# }
# ]

# %%
show_digit(valid_set[0][230], 'This is a {}'.format(valid_set[1][230]))
